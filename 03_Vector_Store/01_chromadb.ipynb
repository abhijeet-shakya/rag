# %% [markdown]
# ###  Building a RAG System with Langchain and ChromaDB
# #### Introduction
# Retrieval Augmented Generation(RAG) is a powerfull technique that combine the capabilities of large language model with external knowledge retrieval.
# - Langchain: A frameworkd for developing applications powered by language models
# - ChromaDB: A open source vector database for storing and retrieving embeddings.
# - gemini - For embeddings and language model

# %%
import os
from dotenv import load_dotenv
load_dotenv()
